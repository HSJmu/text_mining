# %% [markdown]
# ### 라이브러리 로드

# %%
from torch.utils.data import Dataset, DataLoader
import torch.nn.functional as F
import torch.optim as optim
import torch.nn as nn
import torch

from kobert import get_pytorch_kobert_model
from kobert import get_tokenizer

import gluonnlp as nlp

import numpy as np

# %% [markdown]
# ### 1. 모델 불러오기

# %% [markdown]
# ##### 데이터셋 클래스 정의
# - 모델 학습할 때 사용한 데이터셋 클래스 정의, 입력 데이터와 레이블을 적절한 형태로 변환하여 제공하기 위함

# %%
# dataset
class BERTDataset(Dataset):
    def __init__(self, dataset, sent_idx, label_idx, bert_tokenizer, max_len, pad, pair):
        transform = nlp.data.BERTSentenceTransform(bert_tokenizer, max_seq_length=max_len, pad=pad, pair=pair)
        self.sentences = [transform([i[sent_idx]]) for i in dataset]
        self.labels = [i[label_idx] for i in dataset]

    def __getitem__(self, i):
        return (self.sentences[i] + (self.labels[i], ))

    def __len__(self):
        return (len(self.labels))

# %% [markdown]
# ##### 하이퍼파라미터 및 device 지정
# - 모델 학습 시 사용한 하이퍼파라미터 및 장치 설정을 동일하게 지정

# %%
# hyperparameter
seed = 0
max_len = 64
batch_size = 64
warmup_ratio = 0.1
num_epochs = 5
max_grad_norm = 1
log_interval = 200
learning_rate =  5e-5
device = 'cuda' if torch.cuda.is_available() else 'cpu'

# %% [markdown]
# ##### 모델 클래스 정의와 인스턴스화
# - 학습할 때 사용한 모델 클래스 정의 및 해당 클래스를 사용한 모델 객체 인스턴스화를 통해 모델 구조와 설정 재현

# %%
# KoBERT 모델
class BERTClassifier(nn.Module):
  def __init__(self, bert, hidden_size=768, num_classes=2, dr_rate=None, params=None):
    super(BERTClassifier, self).__init__()
    self.bert = bert
    self.dr_rate = dr_rate

    self.classifier = nn.Linear(hidden_size , num_classes)
    if dr_rate:
      self.dropout = nn.Dropout(p=dr_rate)

  def gen_attention_mask(self, token_ids, valid_length):
    attention_mask = torch.zeros_like(token_ids)
    for i, v in enumerate(valid_length):
      attention_mask[i][:v] = 1
    return attention_mask.float()

  def forward(self, token_ids, valid_length, segment_ids):
    attention_mask = self.gen_attention_mask(token_ids, valid_length)
    _, pooler = self.bert(input_ids = token_ids, token_type_ids = segment_ids.long(), attention_mask = attention_mask.float().to(token_ids.device))
    if self.dr_rate:
        out = self.dropout(pooler)
    else:
        out = pooler
    return self.classifier(out)

# %%
bertmodel, vocab = get_pytorch_kobert_model()
tokenizer = get_tokenizer()
tok = nlp.data.BERTSPTokenizer(tokenizer, vocab, lower=False)

# 모델 불러오기
model = BERTClassifier(bertmodel, dr_rate=0.5).to(device)  # 모델 클래스를 정의하고 인스턴스화
# Out:
# using cached model. /home/gksthwls3566/.cache/kobert_v1.zip
# using cached model. /home/gksthwls3566/.cache/kobert_news_wiki_ko_cased-1087f8699e.spiece
# using cached model. /home/gksthwls3566/.cache/kobert_news_wiki_ko_cased-1087f8699e.spiece

# %% [markdown]
# ##### 저장된 모델 가중치 로드
# - 학습된 모델 가중치

# %%
# 저장된 모델의 가중치 로드
model.load_state_dict(torch.load("naverShoppingReview_state_dict.pt"))
# Out:
# <All keys matched successfully>

# %% [markdown]
# ### 2. 모델 적용 예시
# - 클래스는 총 2개(부정, 긍정)이며 부정, 긍정에 대한 로짓값 비교
# - 각 클래스에 대한 로짓값을 비교해 더 높은 값의 클래스를 예측해줌

# %%
# 예측 함수 생성
def predict(predict_sentence):

    data = [predict_sentence, 0]
    dataset_another = [data]

    another_test = BERTDataset(dataset_another, 0, 1, tok, max_len, True, False)
    test_loader = torch.utils.data.DataLoader(another_test, batch_size=batch_size, num_workers=5)
    
    model.eval()

    for batch_id, (token_ids, valid_length, segment_ids, label) in enumerate(test_loader):
        token_ids = token_ids.long().to(device)
        segment_ids = segment_ids.long().to(device)

        valid_length= valid_length
        label = label.long().to(device)

        out = model(token_ids, valid_length, segment_ids)
        test_eval=[]
        for i in out:
            logits=i
            logits = logits.detach().cpu().numpy()
            if np.argmax(logits) == 0:
                test_eval.append("부정")
            else:
                test_eval.append("긍정")
    return test_eval[0]

# %%
predict("해양 산업에 대한 정부의 지원이 지속해서 상승세를 띄고 있습니다.")
# Out:
# '긍정'

# %%
predict("해양 산업에 대한 정부의 지원이 지속해서 하락세를 띄고 있습니다.")
# Out:
# '부정'

# %% [markdown]
# - 항만 기사 하루치 가져와서 긍부정 진행

# %%
import pandas as pd

test = pd.DataFrame()
for i in range(1,7):
  a = pd.read_csv("./크롤링/항만/2003-05-{:02d}_항만.csv".format(i))
  print(a)
  test = pd.concat([test,a])
# Out:
#                                    기사제목     언론사    년도  월
# 0                [부산/경남]부산항만공사 내년 공식 출범    동아일보  2003  5  \
# 1                   “인천공항 고속도 통행료 인하해야”    동아일보  2003  5
# 2                 광양컨 정보 한눈에 홈페이지 구축 운영    무등일보  2003  5
# 3                       인천항사스의심환자발생사스비상    중부일보  2003  5
# 4                  <2003 핫 이슈> 활개치는 총기류    경향신문  2003  5
# 5                       `민자시설 사용료 인하필요`    매일경제  2003  5
# 6       "노동운동 정치적 이용 안타까워" 항운노력 최봉홍 위원장    문화일보  2003  5
# 7                 SOC 활성화위해 법인세 면제해야-상의   머니투데이  2003  5
# 8                       광양항 인터넷 홈페이지 개설    전남일보  2003  5
# 9                     마산항 부두기능 내년 전면 조정  경남도민일보  2003  5
# 10                      관행어업' 인정돼야 보상가능  경남도민일보  2003  5
# 11  허성관 해양부 장관 PA법 통과 회견 ＇항만공사 후속조치 최선＇    국제신문  2003  5
# 12                            PA법 국회 통과    국제신문  2003  5
# 13                                항만공사란    부산일보  2003  5
# 14                      PA법 국회 통과 의미·내용    부산일보  2003  5
# 15                               새로운 출발    부산일보  2003  5
# 16                       환적 화물 전자상거래 실시    부산일보  2003  5
# 17                          항만공사 설립 본궤도    부산일보  2003  5
# 18                         국제범죄 대응체제 강화    부산일보  2003  5
# 19                  '부산의 자랑거리로 만들고 싶어요'    부산일보  2003  5
# 20                [사설]'사스와의 전쟁' 이제 시작이다  강원도민일보  2003  5
# 21                        사스 방역체계 허점 노출    제민일보  2003  5
# 22                  '평택항과 동등 발전' 전제시 수용   충청투데이  2003  5
# 23                    항만물동량 1분기 4.9% 늘어    서울경제  2003  5
# 24           “SOC사업 참여 민간기업 법인ㆍ부가세 면제를”    서울경제  2003  5
# 25                     선박접안 지장 항만운영 걸림돌    경인일보  2003  5
# 26                     선박접안 지장 항만운영 걸림돌    경인일보  2003  5
# 27                   도항운노동조합 임금협정 갱신·체결    한라일보  2003  5
# 28                      유동인구 방역사업 차질 우려    한라일보  2003  5
# 29                     [ET칼럼]물류비가 곧 경쟁력    전자신문  2003  5
# 30                   [도전! 리딩컴퍼니](4)이에스텍    전자신문  2003  5
# 31             운송하역노조원 7천여명 ‘지입제 폐지’ 시위     한겨레  2003  5
# 32                  현장 / 인천공항·항만 검역 초비상     한겨레  2003  5
# 33                       부산항 항만公社 내년 설립    한국경제  2003  5
# 34                         부산항만공사 내년 설립   헤럴드경제  2003  5
# 35           [금리인하ㆍ추경 5兆 추진] 성장 1%P 올린다    한국경제  2003  5
# 36    정부, 중순께 추경 5兆.. 김부총리 "균형 기조는 지킬것"    한국경제  2003  5
#
#                                                   url
# 0   https://www.donga.com/news/article/all/2003050...  \
# 1   https://www.donga.com/news/article/all/2003050...
# 2          http://www.honam.co.kr/detail/GQFJv6/92679
# 3   www.joongboo.com/?mod=news&act=articleView&idx...
# 4                                                 NaN
# 5                                                 NaN
# 6   http://www.munhwa.com/news/view.html?no=200305...
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19                                                NaN
# 20                                                NaN
# 21                                                NaN
# 22                                                NaN
# 23         http://www.sednews.com/NewsView/1HNE94M180
# 24         http://www.sednews.com/NewsView/1HLVBBVH7V
# 25                                                NaN
# 26                                                NaN
# 27                                                NaN
# 28                                                NaN
# 29                 http://www.etnews.com/200304300165
# 30                 http://www.etnews.com/200304300090
# 31                                                NaN
# 32                                                NaN
# 33                                                NaN
# 34                                                NaN
# 35                                                NaN
# 36                                                NaN
#
#                                                  기사내용
# 0   부산의 숙원인 항만공사가 내년에 공식 출범해 본격적인 부산항 운영을 시작한다.  국...
# 1   부가세와 법인세 인하를 통해 도로, 항만 등 민간자본 유치 사회간접자본(SOC) 사...
# 2   광양컨테이너항의 항만정보를 인터넷으로 제공하기 위한 ‘광양항 홈페이지’가 구축돼 운...
# 3   인천공항을 통해 입국한 국내 첫 사스(SARS 중증급성호흡기증후군) 추정환자 발생에...
# 4   ■잇단 총기사고로 본 실태최근 총기사고가 잇따르면서 우리나라도 더 이상 총기사고 안...
# 5   부가세와 법인세 인하를 통해 도로, 항만 등 민자유치 사회간접자본 사용료를 인하해야...
# 6   “30여년간 노동운동을 하면서 가장 기억에 남는 건 임금교섭과 관련한 일화입니다. ...
# 7   도로,항만, 철도 등 SOC 민간투자사업을 활성화하기 위해서는 민자시설 사용료에 대...
# 8   광양항의 모든 것을 담은 통합 인터넷 홈페이지(www.portgy.com)가 개설됐...
# 9   2부두 7일 준공검사…1부두 등 3곳 용도 폐지 "동북아 물류거점 성장 위해 배후터...
# 10  2003해결합시다시 "항만 어로는 불법"… 어민 "해군 입어허가 얻었다"매립공사 일...
# 11  임시국회 마지막날인 30일 본회의에서 항만공사(PA)법이 통과된 뒤 허성관(사진) ...
# 12  국회는 30일 본회의를 열어 항만공사(PA)법 제정안 등 계류 안건을 처리한 뒤 제...
# 13  항만공사(PA·Port Authority)란 정부의 재산인 항만시설을 출자받아 항만...
# 14  지난 30일 국회서 항만공사(PA)법안이 통과됨으로써 부산항만공사가 출범할 수 있는...
# 15  부산항운노동조합은 1일 오전 부산 동구 부산항운종합복지회관에서 노동절 기념식을 가졌...
# 16  오는 2005년부터 부산항의 환적화물(T/S)에 대한 동북아 e-마켓 플레이스 프로...
# 17  항만공사(PA)법이 지난 30일 국회를 통과함으로써 내년초 항만공사 출범을 위한 설...
# 18  속보=경찰이 지난달 17일 발생한 러시아 마피아 두목 총기 살해사건을 계기로 국제범...
# 19  어린이날(5월5일)이 코앞에 다가오면서 묘한 흥분과 긴장감으로 온 몸이 터져나갈 듯...
# 20  '사스와의 전쟁' 이제 시작이다2003년 05월 01일 (목) 　"환자의 폐렴 증세...
# 21  위험지역 입국자 상당수 소재지 파악안돼사스(SARS:중증급성호흡기증후군)로 인한 때...
# 22  당진항 분리지정이 사실상 무산된 가운데 합동조사반이 제시한 절충안을 당진군이 수용할...
# 23  세계적인 경기침체와 이라크전 발발 등 어려운 국제환경 속에서도 올 1ㆍ4분기 우리나...
# 24  대한상공회의소는 1일 도로ㆍ항만 등 사회간접자본(SOC)사업에 참여하는 민간기업에 ...
# 25  평택항 5번선석에 또 송유관매설 허가   2003년 05월 01일 (목) 김종호 k...
# 26                                             [사진기사]
# 27  제주도항운노동조합(위원장 고승화)은 30일 2003년도 항만하역요금 상향 인가고시에...
# 28  중증급성호흡기증후군 ‘사스’ 추정 환자가 국내로 들어오면서 전염병에 대해 관심이 높...
# 29  ◆박광선 논설위원　 < kspark@etnews.co.kr>  　  　가뜩이나 어려...
# 30  ‘첨단 항해장비 개발로 해난사고 예방과 21세기 디지털 뱃길을 열어간다.’  　이에...
# 31  도로·항만 등 화물운송 노동자들로 이뤄진 전국운송하역노조 소속 조합원 7천여명은 3...
# 32  중증 급성호흡기 증후군(사스)의 유입을 막기 위해 인천공항과 인천항만 양쪽 검역소에...
# 33  내년 초 부산항에 항만공사가 설립된다. 해양수산부는 항만공사법이 국회에서 통과됨에 ...
# 34  부산항만공사 내년 설립 부산항 항만공사(PA)가 내년 초에 설립된다. 해양수산부는 ...
# 35  정부가 경기부양을 위해 콜금리 인하와 함께 최대 5조원의 추가경정예산을 긴급 편성키...
# 36  정부가 경기부양책의 일환으로 추가경정예산을 편성하기로 사실상 확정함에 따라 "추경예...
#                                       기사제목     언론사    년도  월
# 0                                 봄철에 사고많다     MBC  2003  5  \
# 1   “민간시설법인 세금 낮춰야 시설이용료 부담 줄어들어”상공회의소 보고서    서울신문  2003  5
# 2                [표] 신설법인(4월25일 ~ 5월1일) 부산    매일경제  2003  5
# 3                     운송하역노조 파업..철강업계 타격예상   머니투데이  2003  5
# 4                      ＂문화·관광 중심과 경제거점도시로＂  경남도민일보  2003  5
# 5                   하늘에서, 땅에서... 포항 물류난 심각    매일신문  2003  5
# 6                      3국간 환적화물, 미국에서 중국으로    경상일보  2003  5
# 7                     울산항 체선 손실률 400억원대 초과    경상일보  2003  5
# 8               PA출범 허브포트로 가자 도약발판 마련한 부산항    국제신문  2003  5
# 9                             항운노조 노동절 기념식    국제신문  2003  5
# 10                            사스 방역에 허점이라니    제민일보  2003  5
# 11                         항만물동량 이라크전불구 급증   헤럴드경제  2003  5
# 12                          道의회도 천안 아산역 내홍   충청투데이  2003  5
# 13                       '평택·당진항’ 사용안 전면거부    경인일보  2003  5
# 14                       ' 동북아중심 그꿈을 바다에서’    경인일보  2003  5
# 15           시, 송도신항 외자유치 일방추진 ... 사업난항 우려    중부일보  2003  5
#
#                                                   url
# 0   newsearch.imbc.com:80/vss-bin/vss_SR/MBC_News/...  \
# 1   http://www.seoul.co.kr/news/newsView.php?id=20...
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 15  www.joongboo.com/?mod=news&act=articleView&idx...
#
#                                                  기사내용
# 0                       function getParams() { var id
# 1   부가세와 법인세를 낮춰 도로,항만 등 민자유치 사회간접자본 사용료를 내려야 한다는 ...
# 2   ==============================================...
# 3   전국운송하역노동조합(위원장 김종인) 화물연대 포항지부와 경남지부는 5월2일부터 운임...
# 4   ■마산시민의 날 황철곤 시장마산시민의 날을 맞아 1일 시청 대회의실에서는 황철곤 시...
# 5   지난달 30일과 1일 이틀간 사실상의 파업에 들어간 운송하역노조와 화물연대(지입차주...
# 6   울산항에서 처리되는 제3국간 액체환적화물 대부분이 미국에서 들어와 환적작업을 거쳐 ...
# 7   지난해 울산항의 체선손실액이 사상 처음으로 연간 400억원대를 넘어선 것으로 나타났...
# 8   부산항만공사 출범은 해양부와 한국컨테이너부두공단 등에 분산돼 있는 부산항의 개발 관...
# 9   부산항운노조(위원장 박이소)는 1일 오전 부산항운종합복지회관 3층 강당에서 항운노조...
# 10  전 세계를 공포에 떨게 하고 있는 사스(SARS·중증급성호흡기증후군)가 여전히 수그...
# 11  항만물동량 이라크전불구 급증 세계적인 경기침체와 이라크전쟁 등 어려운 국제 환경 속...
# 12  건설교통부 역사명칭심의위원회의 경부고속철도 '천안 아산역' 결정에 대한 지역간 논쟁...
# 13  평택시의회 '항만명칭변경 반대'탄원서 제출키로   2003년 05월 02일 (금) ...
# 14  '동북아중심 그 꿈을 바다에서’ 몰 바다의 날 행사 주제… 30일 5부두서 열려  ...
# 15  인천시가 송도신항 건설을 추진하면서 허가기관인 인천지방해양수산청과 사전협의없이 일방...
#                               기사제목   언론사    년도  월
# 0         화물차 시위... 포항공단 4일째 출하 중단  매일신문  2003  5  \
# 1           온산항 항만공사 고의지연 사업 반납·취소  경상일보  2003  5
# 2                     항만위 참여 보장 요구  부산일보  2003  5
# 3  '부산항 동북아 물류 중심 한계 고부가가치 항만 전환을'  부산일보  2003  5
# 4          '이라크 특수 잡아라' 中企 움직임 본격화  부산일보  2003  5
# 5                신행정수도 대도시와 연계 피해야  중부매일  2003  5
# 6                   ' 인천 百年大計’ 밑거름  경인일보  2003  5
# 7     KOTRA-지방사업본부, 중동 특수에 능동 대응키로  전자신문  2003  5
# 8  美 ABT, 이라크 의료사업 수주 .. 1000만弗 규모  한국경제  2003  5
#
#                                   url
# 0                                 NaN  \
# 1                                 NaN
# 2                                 NaN
# 3                                 NaN
# 4                                 NaN
# 5                                 NaN
# 6                                 NaN
# 7  http://www.etnews.com/200305020147
# 8                                 NaN
#
#                                                 기사내용
# 0  지난달 30일과 1일 이틀간 상경시위를 가졌던 운송하역노조와 화물연대(지입차주) 소...
# 1  온산항내 추진중인 비관리청항만공사 대부분이 사업자의 의지 부족과 법적 미비 등으로 ...
# 2  경남도의회는 2일 본회의에서 신항만 건설과 관련해 항만위원회 구성과 공식 명칭 결정...
# 3  정부가 동북아 물류 중심항(HUB) 구축을 국가전략 목표로 설정,대대적 항만 개발에...
# 4  이라크전 이후 중동특수를 잡기 위한 국내 기업들의 움직임이 부산한 가운데 부산지역 ...
# 5  지역균형 발전을 위한 새로운 행정수도는 기존의 수도권과 연계돼서는 안될 뿐 아니라 ...
# 6  ' 인천 百年大計’ 밑거름 요 정필 결 인천대학의 송도신도시 이전 확점은 인천시가 ...
# 7  KOTRA(대표 오영교)는 이라크전 종결로 중동지역에서 우리 중소기업들이 파고들 수...
# 8  미국의 공공부문 컨설팅업체인 ABT어소시에이츠가 1천만달러 규모의 이라크 의료시스템...
#                              기사제목    언론사    년도  월
# 0          아파트-다중시설 공기質 관리법 내년 시행   동아일보  2003  5  \
# 1  [추경예산 집중 투입방침]신도시-임대주택사업 조기 집행   동아일보  2003  5
# 2                     올 추경 SOC 집중  헤럴드경제  2003  5
#
#                                                  url
# 0  https://www.donga.com/news/article/all/2003050...  \
# 1  https://www.donga.com/news/article/all/2003050...
# 2                                                NaN
#
#                                                 기사내용
# 0  내년 5월부터 아파트 터미널 도서관 등 많은 사람들이 이용하는 시설을 새로 짓거나 ...
# 1  정부는 추가경정예산을 사회간접자본(SOC) 건설과 청년실업 해소에 주로 사용한다. ...
# 2  올 추경 SOC 집중 경기 활성화를 위해 오는 6월 실시되는 추가경정예산 편성은 사...
#                                      기사제목    언론사    년도  월  url
# 0                  사스우려 선박 경고 상하이시, 색깔 활용   국제신문  2003  5  NaN  \
# 1   지방분권 이제 실천이다 2부 동남권을 살리자 ＇클러스터 추진 바람＇   국제신문  2003  5  NaN
# 2  지방분권, 이제 실천이다 2부 동남권을 살리자 ＇광역 산업 클러스터＇   국제신문  2003  5  NaN
# 3                            항만 물동량 소폭 감소   제민일보  2003  5  NaN
# 4                     대규모 개발지에 '특정지역제' 도입  머니투데이  2003  5  NaN
# 5                  내달 편성 추경예산, SOC건설 집중투자   세계일보  2003  5  NaN
# 6      '경제특구 재검토' 배경 - 유치過熱-노동계반발 사전차단 카드   세계일보  2003  5  NaN
#
#                                                 기사내용
# 0  사스(SARS·중증급성호흡기증후군) 확산 방지에 총력전을 펼치고 있는 중국 상하이시...
# 1  ‘클러스터(Cluster·집적단지)’가 홍수를 이루고 있다.새 정부가 권역·지역별로...
# 2  ◇지방분권 시리즈 제2부 동남권을 살리자 - 광역 산업 클러스터-------‘동남권...
# 3  도내 5개항 1분기 실적...서귀포항만 증가제주지역 항만을 통한 화물수송실적이 지난...
# 4  대규모 개발지역에서 기반시설 설치비를 국고에서 지원하고, 민간 사업자에게 세제감면 ...
# 5  경기 활성화를 위한 6월 추가경정예산 편성은 사회간접자본(SOC) 건설에 집중될 것...
# 6  정부와 동북아경제중심추진위원회가 경제자유구역 지정 재검토 의사를 내비친 것은 과열양...
#                                   기사제목     언론사    년도  월
# 0                        정부 금리인하 적극 검토    동아일보  2003  5  \
# 1     특수합금소재 생산 '리퀴드 메탈'…＂평택공단을 생산기지로＂    동아일보  2003  5
# 2                        ▶1면 '신항만'서 계속  경남도민일보  2003  5
# 3                    ＂마전공단보다 진북농단 확대를＂  경남도민일보  2003  5
# 4      [내고장진품명품] (2) "항만 특성살려 세계행사 유치"    매일경제  2003  5
# 5                  "금리 인하 적극 검토해야"(상보)   머니투데이  2003  5
# 6                  [전문]제2차 거시경제점검회의 내용   머니투데이  2003  5
# 7               [CEO이슈]'제2중동특수' 물밑 수주전   머니투데이  2003  5
# 8                  경기부양 여론..추경 IT투자 제기   머니투데이  2003  5
# 9                           도시발전과 인적자본  광주매일신문  2003  5
# 10              신항만 대정부 건의안도의회 임시회서 채택  경남도민일보  2003  5
# 11                       PECT 경영권 향배는?    부산일보  2003  5
# 12                 '소프트웨어' 빠진 市 도시계획위　    부산일보  2003  5
# 13                  日 평화주의 흔들 '우경화' 고개    부산일보  2003  5
# 14                      동해항 컨테이너 부두 시급  강원도민일보  2003  5
# 15                   해양청, 액체화물 유치증대 나서    경상일보  2003  5
# 16                   올 성장률 3~4%대로 떨어질듯   헤럴드경제  2003  5
# 17                      철강 ·관련업체 피해 확산   헤럴드경제  2003  5
# 18         "항만 행정협의회’ 구성 배후단지 개발자율적 추진    광주일보  2003  5
# 19                    적극적 재정정책ㆍ금리인하 검토    서울경제  2003  5
# 20                       中企 중동수출 지원 강화    경인일보  2003  5
# 21                    성장률 3%후반∼4%초반 전망  파이낸셜뉴스  2003  5
# 22               국내기관, 적극적 재정정책 주문(2보)   머니투데이  2003  5
# 23           [여의나루] 사스 검역에 휴대용 열추적기 동원    국민일보  2003  5
# 24  [거시경제 점검회의 뭘 논의했나]“경제 불안심리 안정에 주력”  파이낸셜뉴스  2003  5
# 25     운송하역노조 파업 확산에 춘투까지… ‘물류대란’ 또 오나  파이낸셜뉴스  2003  5
#
#                                                   url
# 0   https://www.donga.com/news/article/all/2003050...  \
# 1   https://www.donga.com/news/article/all/2003050...
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9   http://www.kjdaily.com/read.php3?aid=105214680...
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19         http://www.sednews.com/NewsView/1HMP3HCK5V
# 20                                                NaN
# 21                                                NaN
# 22                                                NaN
# 23                                                NaN
# 24                                                NaN
# 25                                                NaN
#
#                                                  기사내용
# 0   국내 경기가 올 상반기 중 회복되기 어렵고 올해 연간 경제성장률도 3%대 후반∼4%...
# 1   경기 평택시 청북면 어연리의 어연한산공업단지. 약 20만평 규모로 국내에서는 유일하...
# 2   도의회 농수산위는 당초 항만위에 정부와 부산시·경남도가 각각 5명씩의 위원을 추천해...
# 3   ■김정부 의원과 마산시의원 간담회장밋빛 구호 아닌 실현 가능한 정책 요구 김 의원 ...
# 4   이봉순 리컨벤션 사장(42ㆍ사진)은 부산 전시컨벤션 산업을 이끌어가는 주인공 가운데...
# 5   경제전문가들은 상반기중 국내 경제의 위축이 지속될 것으로 전망하고 추경편성과 금리인...
# 6   제2차 거시경제점검회의 주요 발표내용  [경제동향과 전망]  가. 국내외 경제동향 ...
# 7   지난 2일(이하 한국시간) 조지 W 부시 미국 대통령이 걸프해에서 샌디에이고로 귀환...
# 8   민간 경제전문가들이 6일 열린 '거시경제점검회의'에서 추경편성, 금리인하 등 적극적...
# 9   박 상철 전남대 평생교육원장 　 얼마 전까지만 해도 지역간 균형발전 문제를 논할 때...
# 10  경남도의회가 지난달 범도민 대책 기구 구성을 제안한데 이어 대정부 건의안을 채택하는...
# 11  국제통운이 지난 2일 컨테이너부두공단이 보유하고 있던 PECT(신선대부두 운영사) ...
# 12  지구단위 계획 수립 등 부산시의 도시계획 전반에 대해 심의 등을 하는 부산시 도시계...
# 13  최근 이라크 전쟁과 북핵문제 등으로 국제정세가 긴박하게 돌아가면서 영구적인 평화를 ...
# 14  동해항 컨테이너 부두 시급道수출업체 부산·광양항 이용… 육상 운송비 해상 보다 되레...
# 15  울산지방해양수산청이 "액체화물 유치 증대"와 "해양 환경보전 추진"에 적극 나선다....
# 16  올 성장률 3~4%대로 떨어질듯 최근의 경기위축 현상은 대내외적인 불안요인들로 인해...
# 17  철강 ·관련업체 피해 확산 국내 철강의 본산지인 포항 지역이 전국운송하역노조와 산하...
# 18  항만건설과 항만배후단지 개발 등 항만업무의 효율적 추진을 위해 관련 기관이 한자리에...
# 19  최근의 경기위축은 대내외적인 불안요인들로 인해 상반기중 지속되고 경제성장률은 3%후...
# 20  中企 중동수출 지원 강화 코트라，시장개척단 파견·현지 상담회등 잇달아 개최  코트라...
# 21  최근의 경기위축은 대내외적인 불안요인들로 인해 상반기중 지속되고 경제성장률은 3%후...
# 22  국내연구기관들은 내수위축을 보완하기 위해 우선 적극적인 재정정책 검토를 주문.. 특...
# 23  국무총리실에 설치돼 있는 사스(SARS·급성중증호흡기증후군) 대책본부가 요즘 사스환...
# 24  정부는 올 성장률이 4% 안팎에 머물 것으로 보임에 따라 적극적인 재정정책과 금리인...
# 25  전국운송하역노조 화물연대 파업사태가 전국으로 확대되면서 산업 기초소재인 철강재는 물...

# %%
result_title, result_ariticle = [predict(a) for a in test['기사제목']], [predict(b) for b in test['기사내용']]

# %%
test['기사제목_감정분석'] = result_title
test['기사내용_감정분석'] = result_ariticle

# %%
test.reindex(columns=['기사제목','기사제목_감정분석','기사내용', '기사내용_감정분석','언론사', '년도', '월', 'url'])
# Out:
#                                   기사제목 기사제목_감정분석
# 0               [부산/경남]부산항만공사 내년 공식 출범        긍정  \
# 1                  “인천공항 고속도 통행료 인하해야”        부정
# 2                광양컨 정보 한눈에 홈페이지 구축 운영        긍정
# 3                      인천항사스의심환자발생사스비상        부정
# 4                 <2003 핫 이슈> 활개치는 총기류        긍정
# ..                                 ...       ...
# 21                    성장률 3%후반∼4%초반 전망        부정
# 22               국내기관, 적극적 재정정책 주문(2보)        긍정
# 23           [여의나루] 사스 검역에 휴대용 열추적기 동원        부정
# 24  [거시경제 점검회의 뭘 논의했나]“경제 불안심리 안정에 주력”        부정
# 25     운송하역노조 파업 확산에 춘투까지… ‘물류대란’ 또 오나        부정
#
#                                                  기사내용 기사내용_감정분석     언론사    년도
# 0   부산의 숙원인 항만공사가 내년에 공식 출범해 본격적인 부산항 운영을 시작한다.  국...        긍정    동아일보  2003  \
# 1   부가세와 법인세 인하를 통해 도로, 항만 등 민간자본 유치 사회간접자본(SOC) 사...        부정    동아일보  2003
# 2   광양컨테이너항의 항만정보를 인터넷으로 제공하기 위한 ‘광양항 홈페이지’가 구축돼 운...        긍정    무등일보  2003
# 3   인천공항을 통해 입국한 국내 첫 사스(SARS 중증급성호흡기증후군) 추정환자 발생에...        부정    중부일보  2003
# 4   ■잇단 총기사고로 본 실태최근 총기사고가 잇따르면서 우리나라도 더 이상 총기사고 안...        부정    경향신문  2003
# ..                                                ...       ...     ...   ...
# 21  최근의 경기위축은 대내외적인 불안요인들로 인해 상반기중 지속되고 경제성장률은 3%후...        부정  파이낸셜뉴스  2003
# 22  국내연구기관들은 내수위축을 보완하기 위해 우선 적극적인 재정정책 검토를 주문.. 특...        부정   머니투데이  2003
# 23  국무총리실에 설치돼 있는 사스(SARS·급성중증호흡기증후군) 대책본부가 요즘 사스환...        부정    국민일보  2003
# 24  정부는 올 성장률이 4% 안팎에 머물 것으로 보임에 따라 적극적인 재정정책과 금리인...        긍정  파이낸셜뉴스  2003
# 25  전국운송하역노조 화물연대 파업사태가 전국으로 확대되면서 산업 기초소재인 철강재는 물...        부정  파이낸셜뉴스  2003
#
#     월                                                url
# 0   5  https://www.donga.com/news/article/all/2003050...
# 1   5  https://www.donga.com/news/article/all/2003050...
# 2   5         http://www.honam.co.kr/detail/GQFJv6/92679
# 3   5  www.joongboo.com/?mod=news&act=articleView&idx...
# 4   5                                                NaN
# .. ..                                                ...
# 21  5                                                NaN
# 22  5                                                NaN
# 23  5                                                NaN
# 24  5                                                NaN
# 25  5                                                NaN
#
# [98 rows x 8 columns]

# %%
test.to_csv("./kobert_030501_030507.csv")
